# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pickle
from collections import Counter
import os
import sys

from importlib import reload
import src.utils.utils
reload(src.utils.utils)
from src.utils.utils import top_n_by_interval, top_n_total_revenue, top_n_average_rating

# %%
data_folder = './data/'
pickle_folder = data_folder + 'pickle/'
imdb_folder = data_folder + 'IMDB/'
cmu_folder = data_folder + 'CMU/'

# %%
## Load the data

with open(pickle_folder + 'movies_clean.p', 'rb') as f:
    movie_data = pickle.load(f)

with open(pickle_folder + 'characters_clean.p', 'rb') as f:
    character_data = pickle.load(f)

# %%
movie_data
# Out:
#        Wikipedia_movie_ID              Movie_name  Movie_box_office_revenue  \
# 0                    3217        Army of Darkness                21502796.0
# 1                    3333   The Birth of a Nation                50000000.0
# 2                    3746            Blade Runner                33139618.0
# 3                    3837         Blazing Saddles               119500000.0
# 4                    3947             Blue Velvet                 8551228.0
# ...                   ...                     ...                       ...
# 34784            36674310  Mystery of Marie Roget                       NaN
# 34785            36683360   2016: Obama's America                33449086.0
# 34786            36814246              Eraserhead                 7000000.0
# 34788            36929245         Before Midnight                       NaN
# 34789            37373877            Crazy Eights                       NaN
#
#        Year Year_Interval  nb_of_Genres  Genre_Action  Genre_Action/Adventure  \
# 0      1992     1975-1995            12          True                    True
# 1      1915     1915-1935             7         False                   False
# 2      1982     1975-1995            12         False                   False
# 3      1974     1955-1975             3         False                   False
# 4      1986     1975-1995             3         False                   False
# ...     ...           ...           ...           ...                     ...
# 34784  1942     1935-1955             1         False                   False
# 34785  2012     1995-2015             1         False                   False
# 34786  1977     1975-1995            10         False                   False
# 34788  2013     1995-2015             2         False                   False
# 34789  2006     1995-2015             2         False                   False
#
#        Genre_Adventure  Genre_Animation  ...  Country_Germany  \
# 0                False            False  ...            False
# 1                False            False  ...            False
# 2                False            False  ...            False
# 3                False            False  ...            False
# 4                False            False  ...            False
# ...                ...              ...  ...              ...
# 34784            False            False  ...            False
# 34785            False            False  ...            False
# 34786            False            False  ...            False
# 34788            False            False  ...            False
# 34789            False            False  ...            False
#
#        Country_Hong Kong  Country_India  Country_Italy  Country_Japan  \
# 0                  False          False          False          False
# 1                  False          False          False          False
# 2                   True          False          False          False
# 3                  False          False          False          False
# 4                  False          False          False          False
# ...                  ...            ...            ...            ...
# 34784              False          False          False          False
# 34785              False          False          False          False
# 34786              False          False          False          False
# 34788              False          False          False          False
# 34789              False          False          False          False
#
#        Country_Other  Country_United Kingdom  \
# 0              False                   False
# 1              False                   False
# 2              False                   False
# 3              False                   False
# 4              False                   False
# ...              ...                     ...
# 34784          False                   False
# 34785          False                   False
# 34786          False                   False
# 34788          False                   False
# 34789          False                   False
#
#        Country_United States of America  averageRating  numVotes
# 0                                  True            7.4  197717.0
# 1                                  True            6.1   26681.0
# 2                                  True            8.1  835060.0
# 3                                  True            7.7  155432.0
# 4                                  True            7.7  219742.0
# ...                                 ...            ...       ...
# 34784                              True            5.9     371.0
# 34785                              True            4.8   11049.0
# 34786                              True            7.3  130107.0
# 34788                              True            7.9  175072.0
# 34789                              True            3.8    3387.0
#
# [25184 rows x 73 columns]

# %%
movie_data.isna().sum()
# Out:
# Wikipedia_movie_ID                      0
# Movie_name                              0
# Movie_box_office_revenue            18274
# Year                                    0
# Year_Interval                           0
#                                     ...
# Country_Other                           0
# Country_United Kingdom                  0
# Country_United States of America        0
# averageRating                           0
# numVotes                                0
# Length: 73, dtype: int64

# %%
df_corr = movie_data.copy()

# %%
df_corr.columns
# Out:
# Index(['Wikipedia_movie_ID', 'Movie_name', 'Movie_box_office_revenue', 'Year',
#        'Year_Interval', 'nb_of_Genres', 'Genre_Action',
#        'Genre_Action/Adventure', 'Genre_Adventure', 'Genre_Animation',
#        'Genre_Biographical film', 'Genre_Biography', 'Genre_Black comedy',
#        'Genre_Black-and-white', 'Genre_Bollywood', 'Genre_Chinese Movies',
#        'Genre_Comedy', 'Genre_Comedy film', 'Genre_Comedy-drama',
#        'Genre_Crime Fiction', 'Genre_Crime Thriller', 'Genre_Documentary',
#        'Genre_Drama', 'Genre_Family Drama', 'Genre_Family Film',
#        'Genre_Fantasy', 'Genre_Film adaptation', 'Genre_Horror', 'Genre_Indie',
#        'Genre_Japanese Movies', 'Genre_LGBT', 'Genre_Musical', 'Genre_Mystery',
#        'Genre_Other', 'Genre_Period piece', 'Genre_Psychological thriller',
#        'Genre_Romance Film', 'Genre_Romantic comedy', 'Genre_Romantic drama',
#        'Genre_Science Fiction', 'Genre_Short Film', 'Genre_Silent film',
#        'Genre_Sports', 'Genre_Thriller', 'Genre_War film', 'Genre_Western',
#        'Genre_World cinema', 'nb_of_Languages', 'lang_english', 'lang_french',
#        'lang_german', 'lang_hindi', 'lang_italian', 'lang_japanese',
#        'lang_other', 'lang_silent film', 'lang_spanish',
#        'lang_standard mandarin', 'lang_tamil', 'nb_of_Countries',
#        'Country_Argentina', 'Country_Canada', 'Country_France',
#        'Country_Germany', 'Country_Hong Kong', 'Country_India',
#        'Country_Italy', 'Country_Japan', 'Country_Other',
#        'Country_United Kingdom', 'Country_United States of America',
#        'averageRating', 'numVotes'],
#       dtype='object')

# %%
# Drop the missing values in Movie_box_office column
df_corr.dropna(subset=['Movie_box_office_revenue'], inplace=True)

# %%
df_corr.drop(columns=['Wikipedia_movie_ID', 'Movie_name' ], inplace=True)

# %%
df_corr.columns
# Out:
# Index(['Movie_box_office_revenue', 'Year', 'Year_Interval', 'nb_of_Genres',
#        'Genre_Action', 'Genre_Action/Adventure', 'Genre_Adventure',
#        'Genre_Animation', 'Genre_Biographical film', 'Genre_Biography',
#        'Genre_Black comedy', 'Genre_Black-and-white', 'Genre_Bollywood',
#        'Genre_Chinese Movies', 'Genre_Comedy', 'Genre_Comedy film',
#        'Genre_Comedy-drama', 'Genre_Crime Fiction', 'Genre_Crime Thriller',
#        'Genre_Documentary', 'Genre_Drama', 'Genre_Family Drama',
#        'Genre_Family Film', 'Genre_Fantasy', 'Genre_Film adaptation',
#        'Genre_Horror', 'Genre_Indie', 'Genre_Japanese Movies', 'Genre_LGBT',
#        'Genre_Musical', 'Genre_Mystery', 'Genre_Other', 'Genre_Period piece',
#        'Genre_Psychological thriller', 'Genre_Romance Film',
#        'Genre_Romantic comedy', 'Genre_Romantic drama',
#        'Genre_Science Fiction', 'Genre_Short Film', 'Genre_Silent film',
#        'Genre_Sports', 'Genre_Thriller', 'Genre_War film', 'Genre_Western',
#        'Genre_World cinema', 'nb_of_Languages', 'lang_english', 'lang_french',
#        'lang_german', 'lang_hindi', 'lang_italian', 'lang_japanese',
#        'lang_other', 'lang_silent film', 'lang_spanish',
#        'lang_standard mandarin', 'lang_tamil', 'nb_of_Countries',
#        'Country_Argentina', 'Country_Canada', 'Country_France',
#        'Country_Germany', 'Country_Hong Kong', 'Country_India',
#        'Country_Italy', 'Country_Japan', 'Country_Other',
#        'Country_United Kingdom', 'Country_United States of America',
#        'averageRating', 'numVotes'],
#       dtype='object')

# %%
df_corr[df_corr.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Movie_box_office_revenue, Year, Year_Interval, nb_of_Genres, Genre_Action, Genre_Action/Adventure, Genre_Adventure, Genre_Animation, Genre_Biographical film, Genre_Biography, Genre_Black comedy, Genre_Black-and-white, Genre_Bollywood, Genre_Chinese Movies, Genre_Comedy, Genre_Comedy film, Genre_Comedy-drama, Genre_Crime Fiction, Genre_Crime Thriller, Genre_Documentary, Genre_Drama, Genre_Family Drama, Genre_Family Film, Genre_Fantasy, Genre_Film adaptation, Genre_Horror, Genre_Indie, Genre_Japanese Movies, Genre_LGBT, Genre_Musical, Genre_Mystery, Genre_Other, Genre_Period piece, Genre_Psychological thriller, Genre_Romance Film, Genre_Romantic comedy, Genre_Romantic drama, Genre_Science Fiction, Genre_Short Film, Genre_Silent film, Genre_Sports, Genre_Thriller, Genre_War film, Genre_Western, Genre_World cinema, nb_of_Languages, lang_english, lang_french, lang_german, lang_hindi, lang_italian, lang_japanese, lang_other, lang_silent film, lang_spanish, lang_standard mandarin, lang_tamil, nb_of_Countries, Country_Argentina, Country_Canada, Country_France, Country_Germany, Country_Hong Kong, Country_India, Country_Italy, Country_Japan, Country_Other, Country_United Kingdom, Country_United States of America, averageRating, numVotes]
# Index: []
#
# [0 rows x 71 columns]

# %%
df_corr.dtypes
# Out:
# Movie_box_office_revenue            float64
# Year                                  int64
# Year_Interval                        object
# nb_of_Genres                          int64
# Genre_Action                           bool
#                                      ...
# Country_Other                          bool
# Country_United Kingdom                 bool
# Country_United States of America       bool
# averageRating                       float64
# numVotes                            float64
# Length: 71, dtype: object

# %%
df_corr
# Out:
#        Movie_box_office_revenue  Year Year_Interval  nb_of_Genres  \
# 0                    21502796.0  1992     1975-1995            12
# 1                    50000000.0  1915     1915-1935             7
# 2                    33139618.0  1982     1975-1995            12
# 3                   119500000.0  1974     1955-1975             3
# 4                     8551228.0  1986     1975-1995             3
# ...                         ...   ...           ...           ...
# 34699                 1000000.0  1953     1935-1955             1
# 34700                 1000000.0  1953     1935-1955             3
# 34707                 1025000.0  1951     1935-1955             1
# 34785                33449086.0  2012     1995-2015             1
# 34786                 7000000.0  1977     1975-1995            10
#
#        Genre_Action  Genre_Action/Adventure  Genre_Adventure  Genre_Animation  \
# 0              True                    True            False            False
# 1             False                   False            False            False
# 2             False                   False            False            False
# 3             False                   False            False            False
# 4             False                   False            False            False
# ...             ...                     ...              ...              ...
# 34699         False                   False            False            False
# 34700         False                   False             True            False
# 34707         False                   False            False            False
# 34785         False                   False            False            False
# 34786         False                   False            False            False
#
#        Genre_Biographical film  Genre_Biography  ...  Country_Germany  \
# 0                        False            False  ...            False
# 1                        False            False  ...            False
# 2                        False            False  ...            False
# 3                        False            False  ...            False
# 4                        False            False  ...            False
# ...                        ...              ...  ...              ...
# 34699                    False            False  ...            False
# 34700                    False            False  ...            False
# 34707                    False            False  ...            False
# 34785                    False            False  ...            False
# 34786                    False            False  ...            False
#
#        Country_Hong Kong  Country_India  Country_Italy  Country_Japan  \
# 0                  False          False          False          False
# 1                  False          False          False          False
# 2                   True          False          False          False
# 3                  False          False          False          False
# 4                  False          False          False          False
# ...                  ...            ...            ...            ...
# 34699              False          False          False          False
# 34700              False          False          False          False
# 34707              False          False          False          False
# 34785              False          False          False          False
# 34786              False          False          False          False
#
#        Country_Other  Country_United Kingdom  \
# 0              False                   False
# 1              False                   False
# 2              False                   False
# 3              False                   False
# 4              False                   False
# ...              ...                     ...
# 34699          False                   False
# 34700          False                   False
# 34707          False                   False
# 34785          False                   False
# 34786          False                   False
#
#        Country_United States of America  averageRating  numVotes
# 0                                  True            7.4  197717.0
# 1                                  True            6.1   26681.0
# 2                                  True            8.1  835060.0
# 3                                  True            7.7  155432.0
# 4                                  True            7.7  219742.0
# ...                                 ...            ...       ...
# 34699                              True            5.4     505.0
# 34700                              True            6.3     397.0
# 34707                              True            6.1     243.0
# 34785                              True            4.8   11049.0
# 34786                              True            7.3  130107.0
#
# [6910 rows x 71 columns]

# %%
# Convert the Year_interval column to a categorical column
categorical_columns = ['Year_Interval']
other_columns = [col for col in df_corr.columns if col not in categorical_columns]
features = pd.get_dummies(df_corr[categorical_columns])
df_corr_encoded = pd.concat([df_corr[other_columns], features], axis=1)
df_corr_encoded
# Out:
#        Movie_box_office_revenue  Year  nb_of_Genres  Genre_Action  \
# 0                    21502796.0  1992            12          True
# 1                    50000000.0  1915             7         False
# 2                    33139618.0  1982            12         False
# 3                   119500000.0  1974             3         False
# 4                     8551228.0  1986             3         False
# ...                         ...   ...           ...           ...
# 34699                 1000000.0  1953             1         False
# 34700                 1000000.0  1953             3         False
# 34707                 1025000.0  1951             1         False
# 34785                33449086.0  2012             1         False
# 34786                 7000000.0  1977            10         False
#
#        Genre_Action/Adventure  Genre_Adventure  Genre_Animation  \
# 0                        True            False            False
# 1                       False            False            False
# 2                       False            False            False
# 3                       False            False            False
# 4                       False            False            False
# ...                       ...              ...              ...
# 34699                   False            False            False
# 34700                   False             True            False
# 34707                   False            False            False
# 34785                   False            False            False
# 34786                   False            False            False
#
#        Genre_Biographical film  Genre_Biography  Genre_Black comedy  ...  \
# 0                        False            False                True  ...
# 1                        False            False               False  ...
# 2                        False            False               False  ...
# 3                        False            False               False  ...
# 4                        False            False               False  ...
# ...                        ...              ...                 ...  ...
# 34699                    False            False               False  ...
# 34700                    False            False               False  ...
# 34707                    False            False               False  ...
# 34785                    False            False               False  ...
# 34786                    False            False               False  ...
#
#        Country_Other  Country_United Kingdom  \
# 0              False                   False
# 1              False                   False
# 2              False                   False
# 3              False                   False
# 4              False                   False
# ...              ...                     ...
# 34699          False                   False
# 34700          False                   False
# 34707          False                   False
# 34785          False                   False
# 34786          False                   False
#
#        Country_United States of America  averageRating  numVotes  \
# 0                                  True            7.4  197717.0
# 1                                  True            6.1   26681.0
# 2                                  True            8.1  835060.0
# 3                                  True            7.7  155432.0
# 4                                  True            7.7  219742.0
# ...                                 ...            ...       ...
# 34699                              True            5.4     505.0
# 34700                              True            6.3     397.0
# 34707                              True            6.1     243.0
# 34785                              True            4.8   11049.0
# 34786                              True            7.3  130107.0
#
#        Year_Interval_1915-1935  Year_Interval_1935-1955  \
# 0                        False                    False
# 1                         True                    False
# 2                        False                    False
# 3                        False                    False
# 4                        False                    False
# ...                        ...                      ...
# 34699                    False                     True
# 34700                    False                     True
# 34707                    False                     True
# 34785                    False                    False
# 34786                    False                    False
#
#        Year_Interval_1955-1975  Year_Interval_1975-1995  \
# 0                        False                     True
# 1                        False                    False
# 2                        False                     True
# 3                         True                    False
# 4                        False                     True
# ...                        ...                      ...
# 34699                    False                    False
# 34700                    False                    False
# 34707                    False                    False
# 34785                    False                    False
# 34786                    False                     True
#
#        Year_Interval_1995-2015
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 34699                    False
# 34700                    False
# 34707                    False
# 34785                     True
# 34786                    False
#
# [6910 rows x 75 columns]

# %%
df_corr_encoded.columns
# Out:
# Index(['Movie_box_office_revenue', 'Year', 'nb_of_Genres', 'Genre_Action',
#        'Genre_Action/Adventure', 'Genre_Adventure', 'Genre_Animation',
#        'Genre_Biographical film', 'Genre_Biography', 'Genre_Black comedy',
#        'Genre_Black-and-white', 'Genre_Bollywood', 'Genre_Chinese Movies',
#        'Genre_Comedy', 'Genre_Comedy film', 'Genre_Comedy-drama',
#        'Genre_Crime Fiction', 'Genre_Crime Thriller', 'Genre_Documentary',
#        'Genre_Drama', 'Genre_Family Drama', 'Genre_Family Film',
#        'Genre_Fantasy', 'Genre_Film adaptation', 'Genre_Horror', 'Genre_Indie',
#        'Genre_Japanese Movies', 'Genre_LGBT', 'Genre_Musical', 'Genre_Mystery',
#        'Genre_Other', 'Genre_Period piece', 'Genre_Psychological thriller',
#        'Genre_Romance Film', 'Genre_Romantic comedy', 'Genre_Romantic drama',
#        'Genre_Science Fiction', 'Genre_Short Film', 'Genre_Silent film',
#        'Genre_Sports', 'Genre_Thriller', 'Genre_War film', 'Genre_Western',
#        'Genre_World cinema', 'nb_of_Languages', 'lang_english', 'lang_french',
#        'lang_german', 'lang_hindi', 'lang_italian', 'lang_japanese',
#        'lang_other', 'lang_silent film', 'lang_spanish',
#        'lang_standard mandarin', 'lang_tamil', 'nb_of_Countries',
#        'Country_Argentina', 'Country_Canada', 'Country_France',
#        'Country_Germany', 'Country_Hong Kong', 'Country_India',
#        'Country_Italy', 'Country_Japan', 'Country_Other',
#        'Country_United Kingdom', 'Country_United States of America',
#        'averageRating', 'numVotes', 'Year_Interval_1915-1935',
#        'Year_Interval_1935-1955', 'Year_Interval_1955-1975',
#        'Year_Interval_1975-1995', 'Year_Interval_1995-2015'],
#       dtype='object')

# %%
df_mod_clean = df_corr.copy()
cpi = pd.read_csv("./data/CPI.csv")

cpi = pd.DataFrame(cpi.groupby('year').apply(lambda x: x['value'].min(),include_groups=False),columns=['cpi'])
base_cpi = cpi.loc[2015].values[0]

df_mod_cpi = df_mod_clean.merge(cpi,left_on='Year',right_on='year',how='left')
df_mod_cpi['Adjusted_Revenue'] = df_mod_cpi['Movie_box_office_revenue']*(base_cpi/df_mod_cpi['cpi'])

for period in df_mod_cpi['Year_Interval'].unique():
    print(period)
    df_period = df_mod_cpi[df_mod_cpi['Year_Interval']==period].drop(columns="Year_Interval")
    display(df_period.corr()['averageRating'].Adjusted_Revenue)
print("\n")

df_mod_cpi['Year_Interval'] = pd.cut(df_mod_cpi['Year'], 
                                       bins=[1914, 1930, 1950, 1970, 2000, 2016], 
                                       labels=['1915-1930', '1930-1950', '1950-1970', '1970-2000', '2000-2015']
                                      ).astype(str)
for period in df_mod_cpi['Year_Interval'].unique():
    print(period)
    df_period = df_mod_cpi[df_mod_cpi['Year_Interval']==period].drop(columns="Year_Interval")
    display(df_period.corr()['averageRating'].Adjusted_Revenue)
# Out:
# 1975-1995
# 0.2974474163340814
# 1915-1935
# 0.01348217197898257
# 1955-1975
# 0.32294541519428244
# 1995-2015
# 0.18108173671902314
# 1935-1955
# 0.1543745548541169
# 1970-2000
# 0.2621499222288998
# 1915-1930
# -0.09017602322624269
# 1930-1950
# 0.17454603833217147
# 1950-1970
# 0.26826790304461007
# 2000-2015
# 0.17498243988887288

# %%
# Perform correlation analysis
correlation_matrix = df_corr_encoded.corr()

# Display the correlation matrix
print(correlation_matrix)

# Optionally, you can visualize the correlation matrix using a heatmap
plt.figure(figsize=(20, 16))
sns.heatmap(correlation_matrix, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Movie Data')
plt.show()
# Out:
#                           Movie_box_office_revenue      Year  nb_of_Genres  \
# Movie_box_office_revenue                  1.000000  0.209062      0.185007
# Year                                      0.209062  1.000000      0.131388
# nb_of_Genres                              0.185007  0.131388      1.000000
# Genre_Action                              0.189744  0.031527      0.268409
# Genre_Action/Adventure                    0.132381 -0.020921      0.276801
# ...                                            ...       ...           ...
# Year_Interval_1915-1935                  -0.053334 -0.373854     -0.032570
# Year_Interval_1935-1955                  -0.127764 -0.658651     -0.168156
# Year_Interval_1955-1975                  -0.067921 -0.372876     -0.026733
# Year_Interval_1975-1995                  -0.078169 -0.084872      0.035923
# Year_Interval_1995-2015                   0.193892  0.742136      0.085277
#
#                           Genre_Action  Genre_Action/Adventure  \
# Movie_box_office_revenue      0.189744                0.132381
# Year                          0.031527               -0.020921
# nb_of_Genres                  0.268409                0.276801
# Genre_Action                  1.000000                0.690279
# Genre_Action/Adventure        0.690279                1.000000
# ...                                ...                     ...
# Year_Interval_1915-1935      -0.033363               -0.020427
# Year_Interval_1935-1955      -0.027877                0.001826
# Year_Interval_1955-1975       0.008174                0.027483
# Year_Interval_1975-1995       0.027433                0.038270
# Year_Interval_1995-2015      -0.005485               -0.045771
#
#                           Genre_Adventure  Genre_Animation  \
# Movie_box_office_revenue         0.227955         0.176046
# Year                            -0.006682         0.065549
# nb_of_Genres                     0.243136         0.154744
# Genre_Action                     0.234963        -0.031849
# Genre_Action/Adventure           0.188095        -0.065815
# ...                                   ...              ...
# Year_Interval_1915-1935         -0.026442        -0.017189
# Year_Interval_1935-1955          0.023699        -0.033358
# Year_Interval_1955-1975          0.004402        -0.027434
# Year_Interval_1975-1995          0.001906        -0.025864
# Year_Interval_1995-2015         -0.011252         0.061523
#
#                           Genre_Biographical film  Genre_Biography  \
# Movie_box_office_revenue                -0.029555        -0.027364
# Year                                    -0.018972         0.032500
# nb_of_Genres                             0.101439         0.102963
# Genre_Action                            -0.047184        -0.056337
# Genre_Action/Adventure                  -0.049587        -0.048605
# ...                                           ...              ...
# Year_Interval_1915-1935                 -0.002190        -0.023931
# Year_Interval_1935-1955                  0.033775        -0.015593
# Year_Interval_1955-1975                  0.017239         0.004025
# Year_Interval_1975-1995                 -0.034162        -0.023615
# Year_Interval_1995-2015                  0.003618         0.034416
#
#                           Genre_Black comedy  ...  Country_Other  \
# Movie_box_office_revenue           -0.042615  ...      -0.034268
# Year                                0.064460  ...       0.209577
# nb_of_Genres                        0.133503  ...      -0.002074
# Genre_Action                       -0.032553  ...      -0.018532
# Genre_Action/Adventure             -0.014389  ...      -0.009881
# ...                                      ...  ...            ...
# Year_Interval_1915-1935            -0.026749  ...      -0.037682
# Year_Interval_1935-1955            -0.061284  ...      -0.110868
# Year_Interval_1955-1975            -0.021500  ...      -0.072738
# Year_Interval_1975-1995             0.014443  ...      -0.114959
# Year_Interval_1995-2015             0.039598  ...       0.216842
#
#                           Country_United Kingdom  \
# Movie_box_office_revenue                0.041841
# Year                                    0.103130
# nb_of_Genres                            0.104187
# Genre_Action                           -0.000871
# Genre_Action/Adventure                  0.007512
# ...                                          ...
# Year_Interval_1915-1935                -0.043879
# Year_Interval_1935-1955                -0.085382
# Year_Interval_1955-1975                -0.006434
# Year_Interval_1975-1995                -0.022457
# Year_Interval_1995-2015                 0.083714
#
#                           Country_United States of America  averageRating  \
# Movie_box_office_revenue                          0.109019       0.166217
# Year                                             -0.182262      -0.123008
# nb_of_Genres                                      0.040789       0.155935
# Genre_Action                                      0.064638      -0.089760
# Genre_Action/Adventure                            0.055835      -0.069718
# ...                                                    ...            ...
# Year_Interval_1915-1935                           0.043732       0.037989
# Year_Interval_1935-1955                           0.106188       0.087797
# Year_Interval_1955-1975                           0.036016       0.106269
# Year_Interval_1975-1995                           0.096830      -0.060034
# Year_Interval_1995-2015                          -0.179681      -0.059889
#
#                           numVotes  Year_Interval_1915-1935  \
# Movie_box_office_revenue  0.640492                -0.053334
# Year                      0.171883                -0.373854
# nb_of_Genres              0.212911                -0.032570
# Genre_Action              0.147644                -0.033363
# Genre_Action/Adventure    0.098941                -0.020427
# ...                            ...                      ...
# Year_Interval_1915-1935  -0.045708                 1.000000
# Year_Interval_1935-1955  -0.109999                -0.038791
# Year_Interval_1955-1975  -0.040690                -0.034761
# Year_Interval_1975-1995  -0.071906                -0.081668
# Year_Interval_1995-2015   0.161814                -0.126697
#
#                           Year_Interval_1935-1955  Year_Interval_1955-1975  \
# Movie_box_office_revenue                -0.127764                -0.067921
# Year                                    -0.658651                -0.372876
# nb_of_Genres                            -0.168156                -0.026733
# Genre_Action                            -0.027877                 0.008174
# Genre_Action/Adventure                   0.001826                 0.027483
# ...                                           ...                      ...
# Year_Interval_1915-1935                 -0.038791                -0.034761
# Year_Interval_1935-1955                  1.000000                -0.089113
# Year_Interval_1955-1975                 -0.089113                 1.000000
# Year_Interval_1975-1995                 -0.209363                -0.187615
# Year_Interval_1995-2015                 -0.324797                -0.291058
#
#                           Year_Interval_1975-1995  Year_Interval_1995-2015
# Movie_box_office_revenue                -0.078169                 0.193892
# Year                                    -0.084872                 0.742136
# nb_of_Genres                             0.035923                 0.085277
# Genre_Action                             0.027433                -0.005485
# Genre_Action/Adventure                   0.038270                -0.045771
# ...                                           ...                      ...
# Year_Interval_1915-1935                 -0.081668                -0.126697
# Year_Interval_1935-1955                 -0.209363                -0.324797
# Year_Interval_1955-1975                 -0.187615                -0.291058
# Year_Interval_1975-1995                  1.000000                -0.683814
# Year_Interval_1995-2015                 -0.683814                 1.000000
#
# [75 rows x 75 columns]

# %%
# Calculate the correlation of each column with the target category 'averageRating'
correlation_with_target = correlation_matrix['averageRating'].sort_values(ascending=False)

# Plot the bar chart
plt.figure(figsize=(20, 5))
correlation_with_target.plot(kind='bar', color= 'lightblue', edgecolor='black')
plt.title('Correlation of Columns with averageRating')
plt.xlabel('Columns')
plt.ylabel('Correlation Coefficient')
plt.show()
